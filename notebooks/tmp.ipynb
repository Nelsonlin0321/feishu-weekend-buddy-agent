# %%
import sys
sys.path.insert(0,"/Volumes/mnt/Workspace/feishu-weekend-buddy-agent")

# %%
import os
import dotenv

# %%
dotenv.load_dotenv()

# %%
from src.prompt import SYSTEM_PROMPT
from src.agent import build_agent
from src.types.context import FeishuRuntimeContext

# %%
agent = build_agent(system_prompt=SYSTEM_PROMPT)

# %%
open_id = "ou_testing"
history_to_load=10

# %%
config = {
    "configurable": {"thread_id": f"feishu:{open_id}"},
    "recursion_limit": 50,
}

# %%
context = FeishuRuntimeContext(open_id=open_id, history_to_load=history_to_load)

# %%
message  = "I will go to the supermarket tmr 3.PM - 3.PM to buy an apple it. Please write my schedule"

# %%
# events = agent.stream(
#     {"messages": [{"role": "user", "content": "I will go to the supermarket tmr 3.PM - 3.PM to Apple it. Please directly write my schedule"}]},
#     context=context,
# )
# content:str=""
# for event in events:
#     if "model" in event:
#         if "messages" in event["model"]:
#             message = event["model"]["messages"][-1]
#             message.pretty_print()
#             content = message.content

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content":message }]},
    config=config,
    context=context,
)
# reply_obj = result["messages"][-1].content

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content":"Any schedule tomorrow afternoon ?" }]},
    config=config,
    context=context,
)
# reply_obj = result["messages"][-1].content

# %%
result
